# %%
import os
import tensorflow as tf
from PIL import Image
from nets import nets_factory
import numpy as np

# %%
CHAR_SET_LEN = 10
#image height
IMAGE_HEIGHT = 60
#image width
IMAGE_WIDTH = 160
#batch size
BATCH_SIZE = 32
#tfrecord file path
TFRECOD_FILE = " /train.tfrecords"

#placeholder
x = tf.placeholder(tf.float32,[None,224,224])
y0 = tf.placeholder(tf.float32,[None])
y1 = tf.placeholder(tf.float32,[None])
y2 = tf.placeholder(tf.float32,[None])
y3 = tf.placeholder(tf.float32,[None])

#define the learning rate
lr = tf.Variable(0.003, dtype=tf.float32)

# import image data from tfrecords
def read_and_decode(filename):
    filename_queue = tf.train.string_input_producer([filename])
    reader = tf.TFRecordReader()
    #The read function takes the filename queue, dequeues file names and extracts the image and label
    _,serialized_example = reader.read(filename_queue)
    features = tf.parse_single_example(serialized_example,
                                      features={
                                          'image':tf.FixedLenFeature([],tf.string),
                                          'label0':tf.FixedLenFeature([],tf.int64),
                                          'label1':tf.FixedLenFeature([],tf.int64),
                                          'label2':tf.FixedLenFeature([],tf.int64),
                                          'label3':tf.FixedLenFeature([],tf.int64),
                                      })
    # get the image data
    image = tf.decode_raw(features['image'],tf.uint8)
    image = tf.reshape(image,[224,224])
    #image preprocessing
    image = tf.cast(image,tf.float32) / 255.0
    image = tf.subtract(image,0.5)
    image = tf.multiply(image,2.0)
    
    #get the label
    label0 = tf.cast(features['label0'],tf.int32)
    label1 = tf.cast(features['label1'],tf.int32)
    label2 = tf.cast(features['label2'],tf.int32)
    label3 = tf.cast(features['label3'],tf.int32)
    
    return image,label0,label1,label2,label3

# %%
# get the image and label infomation
image,label0,label1,label2,label3 = read_and_decode(TFRECOD_FILE)

# shuffle the input
image_batch,label1_batch0,label1_batch1,label1_batch2,label1_batch3 = tf.train.shuffle_batch(
    [image,label0,label1,label2,label3],batch_size = BATCH_SIZE,
    capacity = 50000, min_after_dequeue = 10000,num_threads=1)
 
# define the network structure
train_network_fn = nets_factory.get_network_fn('alexnet_v2',
                                              num_classes=CHAR_SET_LEN,
                                              weight_decay=0.0005,
                                              is_training= True)
with tf.Session() as sess:
    
    X = tf.reshape(x,[BATCH_SIZE,224,224,1])
    logits0,logits1,logits2,logits3,end_points = train_network_fn(X)
    
    # convert the label to one_hot
    one_hot_labels0 = tf.one_hot(indices=tf.cast(y0,tf.int32),depth=CHAR_SET_LEN)
    one_hot_labels1 = tf.one_hot(indices=tf.cast(y1,tf.int32),depth=CHAR_SET_LEN)
    one_hot_labels2 = tf.one_hot(indices=tf.cast(y2,tf.int32),depth=CHAR_SET_LEN)
    one_hot_labels3 = tf.one_hot(indices=tf.cast(y3,tf.int32),depth=CHAR_SET_LEN)
    
    # calculate loss
    loss0 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits0,labels=one_hot_labels0))
    loss1 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits1,labels=one_hot_labels1))
    loss2 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits2,labels=one_hot_labels2))
    loss3 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits3,labels=one_hot_labels3))
    
    # calculate the total loss
    total_loss = (loss0 + loss1 + loss2 + loss3) / 4.0
    #optimize the total loss
    optimizer = tf.train.AdamOptimizer(learning_rate=lr).minimize(total_loss)
    
    # calculate the accuracy 
    correct_prediction0 = tf.equal(tf.argmax(one_hot_labels0,1),tf.arg_max(logits0,1))
    accuracy0 = tf.reduce_mean(tf.cast(correct_prediction0,tf.float32))
    
    correct_prediction1 = tf.equal(tf.argmax(one_hot_labels1,1),tf.arg_max(logits1,1))
    accuracy1 = tf.reduce_mean(tf.cast(correct_prediction1,tf.float32))
    
    correct_prediction2 = tf.equal(tf.argmax(one_hot_labels2,1),tf.arg_max(logits2,1))
    accuracy2 = tf.reduce_mean(tf.cast(correct_prediction2,tf.float32))
    
    correct_prediction3 = tf.equal(tf.argmax(one_hot_labels3,1),tf.arg_max(logits3,1))
    accuracy3 = tf.reduce_mean(tf.cast(correct_prediction3,tf.float32))
    
    # save the model
    saver = tf.train.Saver()
    #initialzation
    sess.run(tf.global_variables_initializer())
    
    # 
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(sess=sess,coord=coord)
    
    for i in range(6001):
        b_image,b_label0,b_label1,b_label2,b_label3 = sess.run([image_batch,label1_batch0,label1_batch1,label1_batch2,label1_batch3])
        sess.run(optimizer, feed_dict={x: b_image, y0:b_label0, y1: b_label1, y2 : b_label2, y3:b_label3})
        
        if i % 20 == 0:
            if i % 2000 == 0:
                sess.run(tf.assign(lr,lr/3))
            acc0,acc1,acc2,acc3,loss_=sess.run([accuracy0, accuracy1,accuracy2,accuracy3,total_loss],feed_dict={x: b_image,
                                                                                                             y0: b_label0,
                                                                                                             y1: b_label1,
                                                                                                             y2: b_label2,
                                                                                                             y3: b_label3})
            learning_rate = sess.run(lr)
            print("Iter:%d Loss:%.3f Accuracy:%.2f,%.2f,%.2f,%.2f Learning_rate:%.4f" % (i,loss_,acc0,acc1,acc2,acc3,learning_rate))
            
            if i == 6000:
                saver.save(sess,"captcha/models/crack_captcha.model",global_step=i)
                break
    
    coord.request_stop()
    coord.join(threads)
# Out:
# WARNING:tensorflow:From <ipython-input-4-ea50f663fe36>:37: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From <ipython-input-4-ea50f663fe36>:40: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From <ipython-input-4-ea50f663fe36>:43: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# WARNING:tensorflow:From <ipython-input-4-ea50f663fe36>:46: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# Iter:0 Loss:2839.936 Accuracy:0.19,0.09,0.19,0.19 Learning_rate:0.0010
# Iter:20 Loss:2.300 Accuracy:0.09,0.12,0.12,0.12 Learning_rate:0.0010
# Iter:40 Loss:2.312 Accuracy:0.12,0.09,0.12,0.06 Learning_rate:0.0010
# Iter:60 Loss:2.309 Accuracy:0.09,0.16,0.06,0.09 Learning_rate:0.0010
# Iter:80 Loss:2.310 Accuracy:0.19,0.06,0.06,0.12 Learning_rate:0.0010
# Iter:100 Loss:2.308 Accuracy:0.09,0.06,0.00,0.12 Learning_rate:0.0010
# Iter:120 Loss:2.306 Accuracy:0.09,0.09,0.25,0.09 Learning_rate:0.0010
# Iter:140 Loss:2.313 Accuracy:0.03,0.03,0.16,0.06 Learning_rate:0.0010
# Iter:160 Loss:2.309 Accuracy:0.19,0.16,0.09,0.03 Learning_rate:0.0010
# Iter:180 Loss:2.316 Accuracy:0.12,0.12,0.09,0.06 Learning_rate:0.0010
# Iter:200 Loss:2.292 Accuracy:0.16,0.06,0.09,0.16 Learning_rate:0.0010
# Iter:220 Loss:2.307 Accuracy:0.16,0.12,0.09,0.03 Learning_rate:0.0010
# Iter:240 Loss:2.305 Accuracy:0.12,0.06,0.09,0.09 Learning_rate:0.0010
# Iter:260 Loss:2.307 Accuracy:0.12,0.16,0.09,0.12 Learning_rate:0.0010
# Iter:280 Loss:2.309 Accuracy:0.06,0.09,0.06,0.06 Learning_rate:0.0010
# Iter:300 Loss:2.305 Accuracy:0.12,0.06,0.06,0.09 Learning_rate:0.0010
# Iter:320 Loss:2.306 Accuracy:0.06,0.12,0.22,0.12 Learning_rate:0.0010
# Iter:340 Loss:2.306 Accuracy:0.06,0.09,0.09,0.06 Learning_rate:0.0010
# Iter:360 Loss:2.295 Accuracy:0.19,0.09,0.12,0.25 Learning_rate:0.0010
# Iter:380 Loss:2.299 Accuracy:0.06,0.09,0.03,0.09 Learning_rate:0.0010
# Iter:400 Loss:2.298 Accuracy:0.06,0.19,0.16,0.09 Learning_rate:0.0010
# Iter:420 Loss:2.284 Accuracy:0.22,0.09,0.06,0.06 Learning_rate:0.0010
# Iter:440 Loss:2.293 Accuracy:0.19,0.16,0.12,0.09 Learning_rate:0.0010
# Iter:460 Loss:2.332 Accuracy:0.22,0.09,0.09,0.06 Learning_rate:0.0010
# Iter:480 Loss:2.301 Accuracy:0.12,0.06,0.12,0.09 Learning_rate:0.0010
# Iter:500 Loss:2.320 Accuracy:0.12,0.16,0.16,0.12 Learning_rate:0.0010
# Iter:520 Loss:2.304 Accuracy:0.22,0.09,0.09,0.09 Learning_rate:0.0010
# Iter:540 Loss:2.275 Accuracy:0.09,0.28,0.19,0.12 Learning_rate:0.0010
# Iter:560 Loss:2.295 Accuracy:0.09,0.12,0.19,0.06 Learning_rate:0.0010
# Iter:580 Loss:2.297 Accuracy:0.16,0.12,0.16,0.06 Learning_rate:0.0010
# Iter:600 Loss:2.221 Accuracy:0.22,0.16,0.12,0.25 Learning_rate:0.0010
# Iter:620 Loss:2.269 Accuracy:0.28,0.06,0.06,0.06 Learning_rate:0.0010
# Iter:640 Loss:2.233 Accuracy:0.31,0.06,0.06,0.06 Learning_rate:0.0010
# Iter:660 Loss:2.164 Accuracy:0.56,0.16,0.12,0.06 Learning_rate:0.0010
# Iter:680 Loss:2.123 Accuracy:0.38,0.12,0.12,0.06 Learning_rate:0.0010
# Iter:700 Loss:2.026 Accuracy:0.53,0.16,0.12,0.19 Learning_rate:0.0010
# Iter:720 Loss:2.073 Accuracy:0.53,0.06,0.16,0.09 Learning_rate:0.0010
# Iter:740 Loss:1.977 Accuracy:0.44,0.16,0.16,0.06 Learning_rate:0.0010
# Iter:760 Loss:2.063 Accuracy:0.56,0.16,0.09,0.16 Learning_rate:0.0010
# Iter:780 Loss:2.006 Accuracy:0.62,0.16,0.12,0.12 Learning_rate:0.0010
# Iter:800 Loss:1.997 Accuracy:0.56,0.12,0.16,0.12 Learning_rate:0.0010
# Iter:820 Loss:1.967 Accuracy:0.62,0.25,0.09,0.22 Learning_rate:0.0010
# Iter:840 Loss:1.988 Accuracy:0.59,0.03,0.12,0.12 Learning_rate:0.0010
# Iter:860 Loss:1.917 Accuracy:0.62,0.22,0.22,0.03 Learning_rate:0.0010
# Iter:880 Loss:1.883 Accuracy:0.72,0.25,0.09,0.09 Learning_rate:0.0010
# Iter:900 Loss:1.874 Accuracy:0.88,0.22,0.09,0.06 Learning_rate:0.0010
# Iter:920 Loss:1.942 Accuracy:0.72,0.12,0.16,0.06 Learning_rate:0.0010
# Iter:940 Loss:1.876 Accuracy:0.81,0.16,0.09,0.06 Learning_rate:0.0010
# Iter:960 Loss:1.873 Accuracy:0.78,0.16,0.06,0.16 Learning_rate:0.0010
# Iter:980 Loss:1.855 Accuracy:0.78,0.06,0.03,0.09 Learning_rate:0.0010
# Iter:1000 Loss:1.810 Accuracy:0.94,0.06,0.19,0.12 Learning_rate:0.0010
# Iter:1020 Loss:1.854 Accuracy:0.84,0.06,0.12,0.19 Learning_rate:0.0010
# Iter:1040 Loss:1.771 Accuracy:0.94,0.06,0.25,0.12 Learning_rate:0.0010
# Iter:1060 Loss:1.848 Accuracy:0.84,0.19,0.06,0.12 Learning_rate:0.0010
# Iter:1080 Loss:1.844 Accuracy:0.75,0.12,0.16,0.12 Learning_rate:0.0010
# Iter:1100 Loss:1.768 Accuracy:0.97,0.34,0.03,0.06 Learning_rate:0.0010
# Iter:1120 Loss:1.685 Accuracy:0.88,0.12,0.38,0.09 Learning_rate:0.0010
# Iter:1140 Loss:1.587 Accuracy:0.84,0.28,0.22,0.34 Learning_rate:0.0010
# Iter:1160 Loss:1.668 Accuracy:0.94,0.19,0.34,0.16 Learning_rate:0.0010
# Iter:1180 Loss:1.542 Accuracy:0.84,0.28,0.16,0.38 Learning_rate:0.0010
# Iter:1200 Loss:1.339 Accuracy:0.88,0.38,0.50,0.34 Learning_rate:0.0010
# Iter:1220 Loss:1.491 Accuracy:0.69,0.44,0.28,0.47 Learning_rate:0.0010
# Iter:1240 Loss:1.294 Accuracy:0.81,0.44,0.44,0.50 Learning_rate:0.0010
# Iter:1260 Loss:1.211 Accuracy:0.84,0.56,0.44,0.59 Learning_rate:0.0010
# Iter:1280 Loss:1.270 Accuracy:0.94,0.53,0.56,0.25 Learning_rate:0.0010
# Iter:1300 Loss:1.027 Accuracy:0.84,0.53,0.53,0.62 Learning_rate:0.0010
# Iter:1320 Loss:1.118 Accuracy:0.91,0.41,0.56,0.41 Learning_rate:0.0010
# Iter:1340 Loss:0.955 Accuracy:0.94,0.59,0.59,0.50 Learning_rate:0.0010
# Iter:1360 Loss:0.989 Accuracy:0.88,0.56,0.72,0.66 Learning_rate:0.0010
# Iter:1380 Loss:0.706 Accuracy:0.94,0.66,0.66,0.59 Learning_rate:0.0010
# Iter:1400 Loss:0.970 Accuracy:0.81,0.56,0.53,0.62 Learning_rate:0.0010
# Iter:1420 Loss:0.757 Accuracy:0.91,0.69,0.88,0.75 Learning_rate:0.0010
# Iter:1440 Loss:0.734 Accuracy:0.91,0.69,0.53,0.69 Learning_rate:0.0010
# Iter:1460 Loss:0.785 Accuracy:0.84,0.84,0.47,0.62 Learning_rate:0.0010
# Iter:1480 Loss:0.649 Accuracy:0.84,0.81,0.69,0.75 Learning_rate:0.0010
# Iter:1500 Loss:0.704 Accuracy:0.91,0.78,0.53,0.53 Learning_rate:0.0010
# Iter:1520 Loss:0.720 Accuracy:0.91,0.78,0.75,0.62 Learning_rate:0.0010
# Iter:1540 Loss:0.714 Accuracy:0.97,0.72,0.59,0.69 Learning_rate:0.0010
# Iter:1560 Loss:0.478 Accuracy:0.91,0.78,0.75,0.84 Learning_rate:0.0010
# Iter:1580 Loss:0.531 Accuracy:0.94,0.81,0.84,0.66 Learning_rate:0.0010
# Iter:1600 Loss:0.543 Accuracy:0.94,0.75,0.78,0.81 Learning_rate:0.0010
# Iter:1620 Loss:0.562 Accuracy:0.94,0.78,0.66,0.75 Learning_rate:0.0010
# Iter:1640 Loss:0.470 Accuracy:0.94,0.88,0.69,0.78 Learning_rate:0.0010
# Iter:1660 Loss:0.588 Accuracy:0.91,0.81,0.78,0.84 Learning_rate:0.0010
# Iter:1680 Loss:0.616 Accuracy:1.00,0.75,0.72,0.84 Learning_rate:0.0010
# Iter:1700 Loss:0.361 Accuracy:1.00,0.88,0.75,0.81 Learning_rate:0.0010
# Iter:1720 Loss:0.381 Accuracy:0.97,0.91,0.91,0.81 Learning_rate:0.0010
# Iter:1740 Loss:0.478 Accuracy:0.94,0.75,0.78,0.94 Learning_rate:0.0010
# Iter:1760 Loss:0.375 Accuracy:0.94,0.84,0.84,0.75 Learning_rate:0.0010
# Iter:1780 Loss:0.351 Accuracy:1.00,0.88,0.78,0.94 Learning_rate:0.0010
# Iter:1800 Loss:0.600 Accuracy:0.88,0.84,0.84,0.81 Learning_rate:0.0010
# Iter:1820 Loss:0.351 Accuracy:0.97,0.84,0.72,0.91 Learning_rate:0.0010
# Iter:1840 Loss:0.498 Accuracy:0.94,0.75,0.81,0.81 Learning_rate:0.0010
# Iter:1860 Loss:0.476 Accuracy:1.00,0.84,0.72,0.72 Learning_rate:0.0010
# Iter:1880 Loss:0.354 Accuracy:1.00,0.88,0.75,0.88 Learning_rate:0.0010
# Iter:1900 Loss:0.407 Accuracy:0.94,0.78,0.94,0.78 Learning_rate:0.0010
# Iter:1920 Loss:0.191 Accuracy:0.97,0.94,0.94,0.91 Learning_rate:0.0010
# Iter:1940 Loss:0.274 Accuracy:0.94,0.88,0.91,0.84 Learning_rate:0.0010
# Iter:1960 Loss:0.335 Accuracy:1.00,0.81,0.75,0.97 Learning_rate:0.0010
# Iter:1980 Loss:0.404 Accuracy:0.94,0.81,0.75,0.88 Learning_rate:0.0010
# Iter:2000 Loss:0.255 Accuracy:1.00,0.91,0.94,0.88 Learning_rate:0.0003
# Iter:2020 Loss:0.271 Accuracy:0.97,0.94,0.84,0.91 Learning_rate:0.0003
# Iter:2040 Loss:0.208 Accuracy:0.91,0.91,0.94,0.97 Learning_rate:0.0003
# Iter:2060 Loss:0.157 Accuracy:1.00,0.97,0.91,0.97 Learning_rate:0.0003
# Iter:2080 Loss:0.297 Accuracy:0.88,0.84,0.78,0.94 Learning_rate:0.0003
# Iter:2100 Loss:0.243 Accuracy:1.00,0.91,0.91,0.88 Learning_rate:0.0003
# Iter:2120 Loss:0.160 Accuracy:0.97,1.00,0.84,0.97 Learning_rate:0.0003
# Iter:2140 Loss:0.224 Accuracy:0.94,0.91,0.94,0.94 Learning_rate:0.0003
# Iter:2160 Loss:0.166 Accuracy:0.94,0.91,0.94,1.00 Learning_rate:0.0003
# Iter:2180 Loss:0.218 Accuracy:0.97,0.97,0.91,0.91 Learning_rate:0.0003
# Iter:2200 Loss:0.165 Accuracy:0.97,0.97,0.88,1.00 Learning_rate:0.0003
# Iter:2220 Loss:0.184 Accuracy:1.00,0.97,0.94,0.88 Learning_rate:0.0003
# Iter:2240 Loss:0.241 Accuracy:1.00,0.75,0.91,0.94 Learning_rate:0.0003
# Iter:2260 Loss:0.270 Accuracy:1.00,0.84,0.84,0.94 Learning_rate:0.0003
# Iter:2280 Loss:0.091 Accuracy:0.97,1.00,1.00,0.97 Learning_rate:0.0003
# Iter:2300 Loss:0.237 Accuracy:0.97,0.91,0.81,0.94 Learning_rate:0.0003
# Iter:2320 Loss:0.329 Accuracy:0.97,0.81,0.81,0.94 Learning_rate:0.0003
# Iter:2340 Loss:0.140 Accuracy:1.00,0.97,0.91,1.00 Learning_rate:0.0003
# Iter:2360 Loss:0.203 Accuracy:0.97,0.94,0.91,0.91 Learning_rate:0.0003
# Iter:2380 Loss:0.137 Accuracy:0.97,0.97,0.97,0.88 Learning_rate:0.0003
# Iter:2400 Loss:0.244 Accuracy:0.97,0.84,0.88,0.94 Learning_rate:0.0003
# Iter:2420 Loss:0.124 Accuracy:1.00,0.97,0.91,0.94 Learning_rate:0.0003
# Iter:2440 Loss:0.114 Accuracy:1.00,1.00,0.88,0.94 Learning_rate:0.0003
# Iter:2460 Loss:0.097 Accuracy:1.00,0.97,0.97,0.97 Learning_rate:0.0003
# Iter:2480 Loss:0.119 Accuracy:0.97,0.97,0.97,0.97 Learning_rate:0.0003
# Iter:2500 Loss:0.237 Accuracy:1.00,0.94,0.84,0.97 Learning_rate:0.0003
# Iter:2520 Loss:0.193 Accuracy:1.00,0.97,0.88,0.91 Learning_rate:0.0003
# Iter:2540 Loss:0.131 Accuracy:1.00,1.00,0.94,0.88 Learning_rate:0.0003
# Iter:2560 Loss:0.135 Accuracy:0.94,0.91,0.88,0.97 Learning_rate:0.0003
# Iter:2580 Loss:0.134 Accuracy:1.00,0.97,0.91,0.97 Learning_rate:0.0003
# Iter:2600 Loss:0.160 Accuracy:0.94,0.94,0.94,0.94 Learning_rate:0.0003
# Iter:2620 Loss:0.118 Accuracy:1.00,0.94,1.00,0.97 Learning_rate:0.0003
# Iter:2640 Loss:0.114 Accuracy:1.00,0.97,0.91,0.97 Learning_rate:0.0003
# Iter:2660 Loss:0.192 Accuracy:0.97,0.97,0.84,1.00 Learning_rate:0.0003
# Iter:2680 Loss:0.102 Accuracy:1.00,1.00,0.91,0.97 Learning_rate:0.0003
# Iter:2700 Loss:0.175 Accuracy:0.94,0.94,0.97,0.97 Learning_rate:0.0003
# Iter:2720 Loss:0.151 Accuracy:0.91,0.94,0.94,0.97 Learning_rate:0.0003
# Iter:2740 Loss:0.069 Accuracy:0.97,0.97,0.97,0.97 Learning_rate:0.0003
# Iter:2760 Loss:0.134 Accuracy:0.97,0.94,1.00,0.97 Learning_rate:0.0003
# Iter:2780 Loss:0.129 Accuracy:0.97,1.00,0.94,0.97 Learning_rate:0.0003
# Iter:2800 Loss:0.063 Accuracy:1.00,1.00,0.97,0.97 Learning_rate:0.0003
# Iter:2820 Loss:0.105 Accuracy:0.97,0.97,0.97,0.94 Learning_rate:0.0003
# Iter:2840 Loss:0.200 Accuracy:0.94,0.88,0.91,0.94 Learning_rate:0.0003
# Iter:2860 Loss:0.111 Accuracy:1.00,0.94,0.88,1.00 Learning_rate:0.0003
# Iter:2880 Loss:0.165 Accuracy:1.00,0.94,0.88,0.91 Learning_rate:0.0003
# Iter:2900 Loss:0.109 Accuracy:0.97,0.97,0.97,0.97 Learning_rate:0.0003
# Iter:2920 Loss:0.144 Accuracy:1.00,0.94,0.94,0.94 Learning_rate:0.0003
# Iter:2940 Loss:0.111 Accuracy:1.00,1.00,0.97,0.91 Learning_rate:0.0003
# Iter:2960 Loss:0.073 Accuracy:1.00,1.00,0.94,0.97 Learning_rate:0.0003
# Iter:2980 Loss:0.088 Accuracy:1.00,0.94,0.94,0.97 Learning_rate:0.0003
# Iter:3000 Loss:0.098 Accuracy:1.00,0.91,0.94,0.97 Learning_rate:0.0003
# Iter:3020 Loss:0.154 Accuracy:1.00,0.97,0.97,0.94 Learning_rate:0.0003
# Iter:3040 Loss:0.057 Accuracy:1.00,0.97,1.00,0.94 Learning_rate:0.0003
# Iter:3060 Loss:0.169 Accuracy:1.00,0.94,0.94,0.94 Learning_rate:0.0003
# Iter:3080 Loss:0.099 Accuracy:0.97,0.94,0.97,0.94 Learning_rate:0.0003
# Iter:3100 Loss:0.130 Accuracy:0.97,0.97,0.88,0.97 Learning_rate:0.0003
# Iter:3120 Loss:0.108 Accuracy:1.00,0.97,0.94,0.97 Learning_rate:0.0003
# Iter:3140 Loss:0.119 Accuracy:1.00,0.97,1.00,0.94 Learning_rate:0.0003
# Iter:3160 Loss:0.126 Accuracy:0.97,0.94,0.97,0.97 Learning_rate:0.0003
# Iter:3180 Loss:0.097 Accuracy:0.97,0.97,0.94,0.97 Learning_rate:0.0003
# Iter:3200 Loss:0.107 Accuracy:1.00,0.94,0.91,1.00 Learning_rate:0.0003
# Iter:3220 Loss:0.154 Accuracy:1.00,0.88,0.97,0.91 Learning_rate:0.0003
# Iter:3240 Loss:0.122 Accuracy:0.94,0.94,0.91,0.97 Learning_rate:0.0003
# Iter:3260 Loss:0.119 Accuracy:1.00,0.94,0.91,1.00 Learning_rate:0.0003
# Iter:3280 Loss:0.139 Accuracy:0.97,0.94,1.00,1.00 Learning_rate:0.0003
# Iter:3300 Loss:0.050 Accuracy:1.00,1.00,1.00,0.94 Learning_rate:0.0003
# Iter:3320 Loss:0.072 Accuracy:1.00,1.00,0.91,1.00 Learning_rate:0.0003
# Iter:3340 Loss:0.111 Accuracy:1.00,0.97,0.94,0.97 Learning_rate:0.0003
# Iter:3360 Loss:0.052 Accuracy:1.00,0.94,1.00,1.00 Learning_rate:0.0003
# Iter:3380 Loss:0.047 Accuracy:0.97,1.00,0.97,1.00 Learning_rate:0.0003
# Iter:3400 Loss:0.165 Accuracy:0.94,0.94,0.97,0.97 Learning_rate:0.0003
# Iter:3420 Loss:0.106 Accuracy:1.00,0.97,0.97,0.94 Learning_rate:0.0003
# Iter:3440 Loss:0.069 Accuracy:1.00,1.00,0.94,1.00 Learning_rate:0.0003
# Iter:3460 Loss:0.116 Accuracy:1.00,0.97,0.88,0.97 Learning_rate:0.0003
# Iter:3480 Loss:0.066 Accuracy:1.00,0.97,0.97,1.00 Learning_rate:0.0003
# Iter:3500 Loss:0.050 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0003
# Iter:3520 Loss:0.104 Accuracy:1.00,0.91,0.88,1.00 Learning_rate:0.0003
# Iter:3540 Loss:0.094 Accuracy:0.97,0.94,1.00,0.94 Learning_rate:0.0003
# Iter:3560 Loss:0.078 Accuracy:1.00,1.00,0.91,1.00 Learning_rate:0.0003
# Iter:3580 Loss:0.080 Accuracy:1.00,0.94,1.00,0.97 Learning_rate:0.0003
# Iter:3600 Loss:0.070 Accuracy:1.00,1.00,0.97,0.97 Learning_rate:0.0003
# Iter:3620 Loss:0.096 Accuracy:0.97,0.94,0.94,0.97 Learning_rate:0.0003
# Iter:3640 Loss:0.060 Accuracy:1.00,1.00,1.00,0.97 Learning_rate:0.0003
# Iter:3660 Loss:0.082 Accuracy:1.00,1.00,0.97,0.91 Learning_rate:0.0003
# Iter:3680 Loss:0.097 Accuracy:0.97,0.91,0.94,1.00 Learning_rate:0.0003
# Iter:3700 Loss:0.075 Accuracy:1.00,0.94,0.97,1.00 Learning_rate:0.0003
# Iter:3720 Loss:0.059 Accuracy:1.00,1.00,0.97,0.97 Learning_rate:0.0003
# Iter:3740 Loss:0.081 Accuracy:1.00,0.94,1.00,0.94 Learning_rate:0.0003
# Iter:3760 Loss:0.037 Accuracy:1.00,1.00,1.00,0.97 Learning_rate:0.0003
# Iter:3780 Loss:0.054 Accuracy:0.97,0.97,1.00,1.00 Learning_rate:0.0003
# Iter:3800 Loss:0.089 Accuracy:0.91,1.00,0.97,0.97 Learning_rate:0.0003
# Iter:3820 Loss:0.040 Accuracy:1.00,1.00,1.00,0.97 Learning_rate:0.0003
# Iter:3840 Loss:0.042 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0003
# Iter:3860 Loss:0.145 Accuracy:1.00,0.97,0.97,0.91 Learning_rate:0.0003
# Iter:3880 Loss:0.083 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0003
# Iter:3900 Loss:0.110 Accuracy:1.00,1.00,0.94,0.97 Learning_rate:0.0003
# Iter:3920 Loss:0.098 Accuracy:0.97,0.91,1.00,1.00 Learning_rate:0.0003
# Iter:3940 Loss:0.045 Accuracy:1.00,1.00,1.00,0.94 Learning_rate:0.0003
# Iter:3960 Loss:0.131 Accuracy:0.97,0.94,0.91,0.97 Learning_rate:0.0003
# Iter:3980 Loss:0.038 Accuracy:1.00,1.00,0.94,1.00 Learning_rate:0.0003
# Iter:4000 Loss:0.100 Accuracy:0.97,1.00,0.94,0.97 Learning_rate:0.0001
# Iter:4020 Loss:0.125 Accuracy:1.00,0.94,0.91,0.97 Learning_rate:0.0001
# Iter:4040 Loss:0.071 Accuracy:1.00,0.97,0.94,1.00 Learning_rate:0.0001
# Iter:4060 Loss:0.014 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:4080 Loss:0.051 Accuracy:1.00,0.97,0.94,1.00 Learning_rate:0.0001
# Iter:4100 Loss:0.088 Accuracy:1.00,0.97,0.88,1.00 Learning_rate:0.0001
# Iter:4120 Loss:0.034 Accuracy:1.00,1.00,0.94,1.00 Learning_rate:0.0001
# Iter:4140 Loss:0.057 Accuracy:1.00,0.97,0.97,0.97 Learning_rate:0.0001
# Iter:4160 Loss:0.019 Accuracy:0.97,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:4180 Loss:0.040 Accuracy:1.00,0.97,0.94,1.00 Learning_rate:0.0001
# Iter:4200 Loss:0.054 Accuracy:0.94,0.97,1.00,0.97 Learning_rate:0.0001
# Iter:4220 Loss:0.027 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:4240 Loss:0.010 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:4260 Loss:0.036 Accuracy:1.00,0.97,0.94,1.00 Learning_rate:0.0001
# Iter:4280 Loss:0.036 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:4300 Loss:0.014 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:4320 Loss:0.015 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:4340 Loss:0.115 Accuracy:0.97,0.94,0.91,0.97 Learning_rate:0.0001
# Iter:4360 Loss:0.035 Accuracy:1.00,1.00,0.97,0.97 Learning_rate:0.0001
# Iter:4380 Loss:0.045 Accuracy:0.94,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:4400 Loss:0.037 Accuracy:0.97,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:4420 Loss:0.078 Accuracy:0.97,0.97,0.97,0.97 Learning_rate:0.0001
# Iter:4440 Loss:0.045 Accuracy:0.97,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:4460 Loss:0.022 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:4480 Loss:0.096 Accuracy:0.97,1.00,0.97,0.97 Learning_rate:0.0001
# Iter:4500 Loss:0.028 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:4520 Loss:0.049 Accuracy:1.00,1.00,1.00,0.94 Learning_rate:0.0001
# Iter:4540 Loss:0.006 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:4560 Loss:0.016 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:4580 Loss:0.029 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:4600 Loss:0.022 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:4620 Loss:0.033 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:4640 Loss:0.031 Accuracy:1.00,1.00,0.97,0.97 Learning_rate:0.0001
# Iter:4660 Loss:0.024 Accuracy:0.97,1.00,1.00,0.97 Learning_rate:0.0001
# Iter:4680 Loss:0.025 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:4700 Loss:0.079 Accuracy:1.00,0.94,0.97,0.97 Learning_rate:0.0001
# Iter:4720 Loss:0.042 Accuracy:1.00,1.00,0.94,0.97 Learning_rate:0.0001
# Iter:4740 Loss:0.028 Accuracy:1.00,1.00,1.00,0.97 Learning_rate:0.0001
# Iter:4760 Loss:0.028 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:4780 Loss:0.021 Accuracy:1.00,1.00,1.00,0.97 Learning_rate:0.0001
# Iter:4800 Loss:0.021 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:4820 Loss:0.032 Accuracy:0.97,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:4840 Loss:0.032 Accuracy:1.00,0.94,1.00,1.00 Learning_rate:0.0001
# Iter:4860 Loss:0.031 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:4880 Loss:0.052 Accuracy:0.97,1.00,1.00,0.91 Learning_rate:0.0001
# Iter:4900 Loss:0.076 Accuracy:1.00,0.97,1.00,0.94 Learning_rate:0.0001
# Iter:4920 Loss:0.019 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:4940 Loss:0.020 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:4960 Loss:0.019 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:4980 Loss:0.017 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5000 Loss:0.026 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:5020 Loss:0.031 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:5040 Loss:0.035 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:5060 Loss:0.009 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5080 Loss:0.021 Accuracy:1.00,0.97,0.97,1.00 Learning_rate:0.0001
# Iter:5100 Loss:0.063 Accuracy:0.97,0.97,0.97,1.00 Learning_rate:0.0001
# Iter:5120 Loss:0.042 Accuracy:1.00,0.97,0.97,0.97 Learning_rate:0.0001
# Iter:5140 Loss:0.032 Accuracy:1.00,0.97,1.00,0.94 Learning_rate:0.0001
# Iter:5160 Loss:0.002 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5180 Loss:0.015 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:5200 Loss:0.022 Accuracy:1.00,1.00,1.00,0.97 Learning_rate:0.0001
# Iter:5220 Loss:0.026 Accuracy:1.00,1.00,0.94,1.00 Learning_rate:0.0001
# Iter:5240 Loss:0.011 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5260 Loss:0.043 Accuracy:1.00,1.00,1.00,0.94 Learning_rate:0.0001
# Iter:5280 Loss:0.044 Accuracy:1.00,1.00,1.00,0.94 Learning_rate:0.0001
# Iter:5300 Loss:0.034 Accuracy:1.00,1.00,1.00,0.94 Learning_rate:0.0001
# Iter:5320 Loss:0.061 Accuracy:1.00,1.00,0.94,1.00 Learning_rate:0.0001
# Iter:5340 Loss:0.021 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5360 Loss:0.038 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:5380 Loss:0.010 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5400 Loss:0.012 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:5420 Loss:0.109 Accuracy:0.97,0.97,0.91,0.97 Learning_rate:0.0001
# Iter:5440 Loss:0.031 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:5460 Loss:0.015 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:5480 Loss:0.023 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:5500 Loss:0.038 Accuracy:1.00,0.94,1.00,0.97 Learning_rate:0.0001
# Iter:5520 Loss:0.047 Accuracy:0.97,0.97,0.97,0.97 Learning_rate:0.0001
# Iter:5540 Loss:0.011 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5560 Loss:0.015 Accuracy:1.00,1.00,1.00,0.97 Learning_rate:0.0001
# Iter:5580 Loss:0.006 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5600 Loss:0.003 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5620 Loss:0.006 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5640 Loss:0.024 Accuracy:0.97,1.00,1.00,0.97 Learning_rate:0.0001
# Iter:5660 Loss:0.018 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:5680 Loss:0.009 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5700 Loss:0.022 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:5720 Loss:0.016 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5740 Loss:0.069 Accuracy:1.00,0.94,0.97,0.97 Learning_rate:0.0001
# Iter:5760 Loss:0.026 Accuracy:1.00,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:5780 Loss:0.046 Accuracy:1.00,1.00,0.94,1.00 Learning_rate:0.0001
# Iter:5800 Loss:0.026 Accuracy:0.97,1.00,0.97,1.00 Learning_rate:0.0001
# Iter:5820 Loss:0.027 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:5840 Loss:0.019 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5860 Loss:0.008 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5880 Loss:0.013 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5900 Loss:0.014 Accuracy:1.00,1.00,1.00,1.00 Learning_rate:0.0001
# Iter:5920 Loss:0.093 Accuracy:1.00,0.97,0.97,1.00 Learning_rate:0.0001
# Iter:5940 Loss:0.028 Accuracy:0.97,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:5960 Loss:0.039 Accuracy:0.94,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:5980 Loss:0.042 Accuracy:1.00,0.97,1.00,1.00 Learning_rate:0.0001
# Iter:6000 Loss:0.024 Accuracy:1.00,0.97,0.97,1.00 Learning_rate:0.0000
